# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import RandomForestClassifier

# %%
df_fan_features = pd.read_csv("../Features/df_fan_feature.csv")
df_fan_target = pd.read_csv("../Features/df_fan_target.csv")
X = df_fan_features
y = df_fan_target.values.ravel()

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, 
    y, 
    test_size=0.2, 
    random_state=69
)
X_train, X_val, y_train, y_val = train_test_split(
    X_train, 
    y_train, 
    test_size=0.05, 
    random_state=69
)

# %%
# define the model
########## Tuned Random Forest #######
model = RandomForestClassifier(
    n_estimators = 500, 
    criterion ='entropy',
    warm_start = True,
    max_features = 'sqrt',
    oob_score = 'True', # more on this below
    random_state=69  
) 

model.fit(X_train, y_train)
# get importance
importance = model.feature_importances_
# summarize feature importance
for i,v in enumerate(importance):
	print('Feature: %0d, Score: %.5f' % (i,v))
# plot feature importance
plt.bar([x for x in range(len(importance))], importance)
plt.show()
# Out:
# Feature: 0, Score: 0.03267
# Feature: 1, Score: 0.03639
# Feature: 2, Score: 0.04980
# Feature: 3, Score: 0.04637
# Feature: 4, Score: 0.01358
# Feature: 5, Score: 0.06145
# Feature: 6, Score: 0.03736
# Feature: 7, Score: 0.06172
# Feature: 8, Score: 0.03840
# Feature: 9, Score: 0.02627
# Feature: 10, Score: 0.03432
# Feature: 11, Score: 0.04153
# Feature: 12, Score: 0.02443
# Feature: 13, Score: 0.02193
# Feature: 14, Score: 0.03393
# Feature: 15, Score: 0.01742
# Feature: 16, Score: 0.00863
# Feature: 17, Score: 0.01826
# Feature: 18, Score: 0.02329
# Feature: 19, Score: 0.06931
# Feature: 20, Score: 0.02268
# Feature: 21, Score: 0.03823
# Feature: 22, Score: 0.04561
# Feature: 23, Score: 0.08171
# Feature: 24, Score: 0.02025
# Feature: 25, Score: 0.01201
# Feature: 26, Score: 0.01981
# Feature: 27, Score: 0.03503
# Feature: 28, Score: 0.02764

# %%
df_important_feature_cols = df_fan_features.drop(columns = ["4", "16", "25"])

# %%
df_important_feature_cols.head()
# Out:
#           0         1         2         3         5         6         7  \
# 0  0.321765  0.993920  0.587307  0.227931  0.454453  0.012064  0.059049
# 1  0.324179  0.997664  0.575122  0.233173  0.581692  0.015197  0.076022
# 2  0.309565  0.992410  0.583972  0.245409  0.515054  0.013476  0.067214
# 3  0.321053  0.994196  0.576258  0.235442  0.570727  0.015205  0.074875
# 4  0.347573  0.981656  0.593205  0.225728  0.491109  0.013466  0.065463
#
#             8           9         10  ...        18        19        20  \
# 0 -439.074188  151.212128 -20.210539  ...  0.028088  0.018938  0.002594
# 1 -440.888489  155.448624 -19.490046  ...  0.030373  0.021426  0.003007
# 2 -440.551361  152.642548 -19.862175  ...  0.027355  0.020326  0.002495
# 3 -448.646210  170.903778 -19.135004  ...  0.027138  0.020827  0.002560
# 4 -442.838745  163.274231 -19.267702  ...  0.028564  0.019928  0.002771
#
#          21        22        23        24        26        27        28
# 0  0.006821  0.011630  0.009338  0.001038  0.038574  0.022062  0.004880
# 1  0.007374  0.013181  0.010397  0.001020  0.031738  0.019542  0.003963
# 2  0.007279  0.012313  0.009822  0.000860  0.034668  0.020863  0.004406
# 3  0.007297  0.013035  0.010333  0.001054  0.028809  0.015656  0.003357
# 4  0.007218  0.013747  0.009737  0.001146  0.028320  0.016588  0.003945
#
# [5 rows x 26 columns]

# %%
X2 = df_important_feature_cols
y2 = df_fan_target.values.ravel()

# %%
X2_train, X2_test, y2_train, y2_test = train_test_split(
    X2, 
    y2, 
    test_size=0.2, 
    random_state=69
)

# %%
from sklearn.ensemble import RandomForestClassifier
# define the model
########## Tuned Random Forest #######
model = RandomForestClassifier(
    n_estimators = 500, 
    criterion ='entropy',
    warm_start = True,
    max_features = 'sqrt',
    oob_score = 'True', # more on this below
    random_state=69  
) 

model.fit(X2_train, y2_train)
# get importance
importance = model2.feature_importances_
# summarize feature importance
for i,v in enumerate(importance):
	print('Feature: %0d, Score: %.5f' % (i,v))
# plot feature importance
plt.bar([x for x in range(len(importance))], importance)
plt.show()
# Out:
# Feature: 0, Score: 0.01489
# Feature: 1, Score: 0.02363
# Feature: 2, Score: 0.08673
# Feature: 3, Score: 0.05128
# Feature: 4, Score: 0.09111
# Feature: 5, Score: 0.01732
# Feature: 6, Score: 0.08408
# Feature: 7, Score: 0.02735
# Feature: 8, Score: 0.02469
# Feature: 9, Score: 0.03947
# Feature: 10, Score: 0.03496
# Feature: 11, Score: 0.01520
# Feature: 12, Score: 0.01777
# Feature: 13, Score: 0.03760
# Feature: 14, Score: 0.01638
# Feature: 15, Score: 0.01067
# Feature: 16, Score: 0.00983
# Feature: 17, Score: 0.09511
# Feature: 18, Score: 0.00886
# Feature: 19, Score: 0.01502
# Feature: 20, Score: 0.08808
# Feature: 21, Score: 0.09146
# Feature: 22, Score: 0.01064
# Feature: 23, Score: 0.01533
# Feature: 24, Score: 0.03180
# Feature: 25, Score: 0.04074
